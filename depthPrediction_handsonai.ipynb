# %%
# !git clone https://github.com/numediart/DepthPrediction.git
# Out:
# Cloning into 'DepthPrediction'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 77 (delta 16), reused 64 (delta 12), pack-reused 0
# Unpacking objects: 100% (77/77), done.

# %%
cd DepthPrediction/
# Out:
# /content/DepthPrediction

# %%
from IPython.display import Image
Image('assets/test_image.jpg', width=640)

# %%
# !python test_simple.py --image_path assets/test_image.jpg --model_name mono+stereo_640x192
# Out:
# -> Downloading pretrained model to models/mono+stereo_640x192.zip
#    Unzipping model...
#    Model unzipped to models/mono+stereo_640x192
# -> Loading model from  models/mono+stereo_640x192
#    Loading pretrained encoder
#    Loading pretrained decoder
# -> Predicting on 1 test images
#    Processed 1 of 1 images - saved prediction to assets/test_image_disp.jpeg
# -> Done!

# %%
Image('assets/test_image_disp.jpeg', width=640)
